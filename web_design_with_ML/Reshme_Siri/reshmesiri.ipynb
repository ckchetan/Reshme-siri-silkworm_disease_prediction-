# %%
from tensorflow.compat.v1 import ConfigProto
from tensorflow.compat.v1 import InteractiveSession

config = ConfigProto()
config.gpu_options.allow_growth = True
session = InteractiveSession(config=config)

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D
from tensorflow.keras.layers import MaxPooling2D
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Dense
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import tensorflow as tf
tf.compat.v1.disable_eager_execution()
import matplotlib.pyplot as plt
import numpy as np
import os

#basic cnn
# Initialising the CNN
classifier = Sequential()

# Step 1 - Convolution
classifier.add(Conv2D(32, (3, 3), input_shape = (128, 128, 3), activation = 'relu'))

# Step 2 - Pooling
classifier.add(MaxPooling2D(pool_size = (2, 2)))

# Adding a second convolutional layer
classifier.add(Conv2D(32, (3, 3), activation = 'relu'))
classifier.add(MaxPooling2D(pool_size = (2, 2)))

# Step 3 - Flattening
classifier.add(Flatten())

# Step 4 - Full connection
classifier.add(Dense(units = 128, activation = 'relu'))
classifier.add(Dense(units = 5, activation = 'sigmoid'))


# Compiling the CNN
classifier.compile(optimizer = 'adam', loss = 'categorical_crossentropy', metrics = ['accuracy'])


train_datagen = ImageDataGenerator(rescale = 1./255, shear_range = 0.2, zoom_range = 0.2, horizontal_flip = True)

test_datagen = ImageDataGenerator(rescale = 1./255)

training_set = train_datagen.flow_from_directory('/content/drive/MyDrive/Genrate-img/datasets/train', # relative path from working directoy
                                                 target_size = (128, 128),
                                                 batch_size = 6, class_mode = 'categorical')
valid_set = test_datagen.flow_from_directory('/content/drive/MyDrive/Genrate-img/datasets/val', # relative path from working directoy
                                             target_size = (128, 128), 
                                        batch_size = 3, class_mode = 'categorical')

labels = (training_set.class_indices)
print(labels)

classifier.fit(training_set,
               epochs = 10,
               validation_data = valid_set)



classifier_json=classifier.to_json()
with open("model2.json", "w") as json_file:
    json_file.write(classifier_json)
# serialize weights to HDF5
    classifier.save_weights("my_model_weights1.h6")
    classifier.save("modellll.h5")
    print("Saved model to disk")
# Out:
# Found 287 images belonging to 5 classes.
# Found 297 images belonging to 5 classes.
# {'flacheria': 0, 'grasseria': 1, 'mascardine': 2, 'pabrin': 3, 'undeseased': 4}
# Epoch 1/10
# 48/48 [==============================] - ETA: 0s - batch: 23.5000 - size: 5.9792 - loss: 1.3297 - accuracy: 0.5436
# /usr/local/lib/python3.9/dist-packages/keras/engine/training_v1.py:2335: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates = self.state_updates
# 48/48 [==============================] - 76s 2s/step - batch: 23.5000 - size: 5.9792 - loss: 1.3298 - accuracy: 0.5436 - val_loss: 0.5741 - val_accuracy: 0.8788
# Epoch 2/10
# 48/48 [==============================] - 13s 280ms/step - batch: 23.5000 - size: 5.9792 - loss: 0.3792 - accuracy: 0.8815 - val_loss: 0.3296 - val_accuracy: 0.8889
# Epoch 3/10
# 48/48 [==============================] - 13s 278ms/step - batch: 23.5000 - size: 5.9792 - loss: 0.2075 - accuracy: 0.9547 - val_loss: 0.0143 - val_accuracy: 1.0000
# Epoch 4/10
# 48/48 [==============================] - 12s 252ms/step - batch: 23.5000 - size: 5.9792 - loss: 0.0742 - accuracy: 0.9826 - val_loss: 0.0336 - val_accuracy: 0.9832
# Epoch 5/10
# 48/48 [==============================] - 12s 247ms/step - batch: 23.5000 - size: 5.9792 - loss: 0.0887 - accuracy: 0.9686 - val_loss: 0.1684 - val_accuracy: 0.9394
# Epoch 6/10
# 48/48 [==============================] - 13s 272ms/step - batch: 23.5000 - size: 5.9792 - loss: 0.0554 - accuracy: 0.9791 - val_loss: 0.0050 - val_accuracy: 1.0000
# Epoch 7/10
# 48/48 [==============================] - 13s 273ms/step - batch: 23.5000 - size: 5.9792 - loss: 0.0626 - accuracy: 0.9826 - val_loss: 0.0011 - val_accuracy: 1.0000
# Epoch 8/10
# 48/48 [==============================] - 13s 273ms/step - batch: 23.5000 - size: 5.9792 - loss: 0.0024 - accuracy: 1.0000 - val_loss: 5.0868e-05 - val_accuracy: 1.0000
# Epoch 9/10
# 48/48 [==============================] - 12s 253ms/step - batch: 23.5000 - size: 5.9792 - loss: 7.8256e-04 - accuracy: 1.0000 - val_loss: 5.2145e-05 - val_accuracy: 1.0000
# Epoch 10/10
# 48/48 [==============================] - 12s 250ms/step - batch: 23.5000 - size: 5.9792 - loss: 3.9276e-04 - accuracy: 1.0000 - val_loss: 4.2150e-05 - val_accuracy: 1.0000
# Saved model to disk

# %%
import cv2
from matplotlib import pyplot as plt
import os
import numpy as np
from tensorflow.keras.preprocessing.image import load_img
from tensorflow.keras.preprocessing.image import img_to_array
from tensorflow.keras.models import load_model

filepath = '/content/modellll.h5'
model = load_model(filepath)
print(model)

print("Model Loaded Successfully")

tomato_plant = cv2.imread('/content/drive/MyDrive/Genrate-img/rename3/pabrindiseased_2_9382732 - Copy.jpg')
test_image = cv2.resize(tomato_plant, (128,128)) # load image 
  
test_image = img_to_array(test_image)/255 # convert image to np array and normalize
test_image = np.expand_dims(test_image, axis = 0) # change dimention 3D to 4D
  
result = model.predict(test_image) # predict diseased palnt or not

print(result)
for i in result:
  if 'e' in str(i):
    print("error")
  else:
    pred = np.argmax(result, axis=1)
    print(pred)
    if pred==0:
       print( "flacheria")
       
    elif pred==1:
        print("grasseria")
        
    elif pred==2:
         print("mascardine")
        
    elif pred==3:
        print("pabrin")
       
    elif pred==4:
         print("undses")
# Out:
# <keras.engine.sequential.Sequential object at 0x7f3c881da250>
# Model Loaded Successfully
# [[0.807251   0.6802608  0.03125429 0.99999046 0.15400454]]
# [3]
# pabrin
